# %%
from connections import DirectedGraph, UndirectedGraph

# %%
g = DirectedGraph()
g.add_node(name='Kate', age=19, sex=False)
g.add_node(name='Pedro', age=21, sex=True)
# Out:
# '7dc623c1d5054ecbace4c41824b259f3'

# %%
g.nodes
# Out:
# {'7a4ef42da39443fcaa27625ad6d276f3': {'name': 'Kate', 'age': 19, 'sex': False},
#  '7dc623c1d5054ecbace4c41824b259f3': {'name': 'Pedro', 'age': 21, 'sex': True}}

# %%
g.add_edge('kate', 'alex', weight=45)
# Out:
# 'f7dcc9424fac4f99887b05c50625e715'

# %%
g.edges
# Out:
# {('kate', 'alex'): {'b398899c19df41b58dfbed20c1904bba': {'weight': 45},
#   'f7dcc9424fac4f99887b05c50625e715': {'weight': 45}}}

# %%
g.nodes
# Out:
# {'7a4ef42da39443fcaa27625ad6d276f3': {'name': 'Kate', 'age': 19, 'sex': False},
#  '7dc623c1d5054ecbace4c41824b259f3': {'name': 'Pedro', 'age': 21, 'sex': True},
#  'kate': {'name': 'Kate'},
#  'alex': {}}
